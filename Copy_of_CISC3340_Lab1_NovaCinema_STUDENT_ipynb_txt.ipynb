# %% [markdown]
# <a href="https://colab.research.google.com/github/juemoore-prog/Rere/blob/main/Copy_of_CISC3340_Lab1_NovaCinema_STUDENT_ipynb_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab #1: Nova Cinema Box Office Assistant
# ### CISC 3340, WK2-3, Getting Started (cont.) & Decisions
#
# **The scenario:** Nova Cinema is a small, independent movie theater that still prices tickets by hand at the box office. The owner has hired you to build a simple Python program that calculates a customer's ticket price instantly.
#
# **How this notebook works:** Each part below has instructions in a text cell, followed by a code cell with some structure already in place. Look for `# TODO` comments and `None` placeholders, those are the parts you need to fill in. Run each cell as you go so you catch mistakes early instead of all at once at the end.
#
# **Submitting:** When you're done, go to **File > Save a copy in GitHub** and save it into the `labs` folder of the repo you set up this week. Then share the Colab link per the submission instructions in the Lab #1 document.

# %% [markdown]
# ---
# ## Part 1: Operators & expressions warm-up
#
# Nova Cinema's "Combo Deal" bundles one ticket, one popcorn, and one drink.
#
# | Item | Price |
# |---|---|
# | Ticket | \$12.50 |
# | Popcorn | \$6.75 |
# | Drink | \$4.25 |
#
# 1. Create a variable for each price.
# 2. Use Python's arithmetic operators to compute the Combo Deal total.
# 3. Nova Cinema is running a 10% discount on the combo this month. Compute the discounted total.
# 4. Print both totals so a cashier could read them at a glance.

# %%
# Part 1: Combo Deal pricing

# TODO: assign the correct prices below
ticket_price = 12.50
popcorn_price = 6.75
drink_price = 4.25

# TODO: compute the combo total using the variables above
combo_total = $23.50

# TODO: compute the discounted total (10% off combo_total)
combo_discounted = $21.15

# TODO: print both totals clearly
print("Combo total: $%.2f" % combo_total)
print("Discounted total: $%.2f" % combo_discounted)
# Out:
#   File "/tmp/ipykernel_1203/3815476213.py", line 9
#     combo_total = $23.50
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---
# ## Part 2: A hex detour, membership cards
#
# Every Nova Cinema membership card has a two-character hex code printed on the back, for example `A3`. The box office computer stores member numbers in decimal, so the register needs to convert the hex code on the card into a decimal number to look someone up.
#
# 1. By hand, work out what `A3` in hex equals in decimal.
# 2. Then check your answer in code using Python's built-in `int()` function.
# 3. Pick two more two-character hex codes of your own, predict their decimal value first, then verify in code.

# %% [markdown]
# **Your hand-worked reasoning for A3 (double-click this cell to edit):**
#
# *Write your reasoning here before running any code.*

# %%
# Part 2: Hex to decimal conversion

# TODO: convert "A3" from hex to decimal using int()
member_id = int("A3", 16)
print("A3 in decimal is", member_id)

# TODO: pick two more hex codes of your own and convert them too
print("1F in decimal is", code1)
print("B0 in decimal is", code2)

# %% [markdown]
# ---
# ## Part 3: Plan the pricing logic in pseudocode
#
# Nova Cinema's actual pricing rules:
#
# | Rule | Price / Adjustment |
# |---|---|
# | Child (under 12) | \$8.00 base |
# | Senior (65 or older) | \$9.00 base |
# | Adult (everyone else) | \$12.50 base |
# | Matinee showing (before 5pm) | \$2.00 off the base price |
# | Member | an additional \$1.00 off |
#
# Before writing any Python, plan the decision logic in plain English below. Work through: what do you check first? What order do the discounts get applied in? What happens if someone is both a senior and a member at a matinee?

# %% [markdown]
# **Your pseudocode (double-click this cell to edit):**
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
# ## Part 4: Implement it with conditionals and Booleans
#
# Turn your Part 3 pseudocode into real Python using `if` / `elif` / `else` and Boolean variables (for example `is_matinee`, `is_member`).
#
# Set your `age`, `is_matinee`, and `is_member` variables by hand at the top of the cell for each test run. Test your program against every row below and confirm your output matches exactly, then change the variables and re-run for the next row.
#
# | Age | Matinee? | Member? | Expected Price |
# |---|---|---|---|
# | 8 | No | No | \$8.00 |
# | 30 | Yes | No | \$10.50 |
# | 70 | No | Yes | \$8.00 |
# | 30 | Yes | Yes | \$9.50 |

# %%
# Part 4: Nova Cinema pricing logic
# Change these three values to test each row in the table, then re-run this cell
age = 30          # TODO: set an age to test
is_matinee = true   # TODO: set True or False
is_member = true    # TODO: set True or False

# TODO: figure out the base price using if / elif / else based on age
if age < 12:
    price = 8.00
elif age >= 65:
    price = 9.00
else:
    price = 12.50

# TODO: apply the matinee discount if is_matinee is True

if is_matinee:
    price = price - 2.00
# TODO: apply the member discount if is_member is True
if is_member:
    price = price - 1.00

# TODO: print the final price
print("Final price: $%.2f" % price)

# %% [markdown]
# ---
# ## Part 5: Knowledge check (20 questions)
#
# This section tests you on all of this week's content, not just the Nova Cinema build. Read each question, work out your answer, then record it in the code cell at the end of this section by replacing `None` with the letter of your choice, as a string, for example `"b"`.
#
# This is closed-note, same as Quiz #1. Work through it on your own before checking anything.

# %% [markdown]
# ### Operators & expressions (Q1 to Q4)
#
# **Q1.** What does `23 % 5` evaluate to in Python? C
# a) 4.6   b) 3   c) 4   d) 0
#
# **Q2.** Following order of operations, what does `2 + 3 * 4` evaluate to? B
# a) 20   b) 14   c) 24   d) 9
#
# **Q3.** Which operator would you use to check whether one number divides evenly into another (remainder of 0)?
# a) `//`   b) `**`   c) `%`   d) `/`
#
# **Q4.** Nova Cinema wants the discounted combo total. Given a variable `combo_total` and a 10% discount, which expression is correct? C
# a) `combo_total - 10`   b) `combo_total * 0.10`   c) `combo_total - (combo_total * 0.10)`   d) `combo_total / 0.10`

# %% [markdown]
# ### Binary & hex (Q5 to Q8)
#
# **Q5.** What base is hexadecimal? D
# a) base 2   b) base 8   c) base 10   d) base 16
#
# **Q6.** What is hex `"1A"` in decimal? A
# a) 26   b) 30   c) 11   d) 16
#
# **Q7.** Why do computers ultimately store all data in binary rather than hex or decimal? B
# a) Binary is easier for humans to read   b) Transistors and circuits naturally represent two states, on or off   c) Hex takes up less memory than binary   d) Decimal isn't supported by circuits
#
# **Q8.** Which converts the hex string `"FF"` into a decimal integer in Python? B
# a) `hex("FF")`   b) `int("FF", 16)`   c) `bin("FF")`   d) `float("FF")`

# %% [markdown]
# ### Algorithms & pseudocode (Q9 to Q12)
#
# **Q9.** What is the main purpose of writing pseudocode before writing real code? B
# a) It's required by Python's syntax   b) It separates planning the logic from wrestling with syntax, so you solve one problem at a time   c) It automatically becomes the final code   d) It replaces the need for testing
#
# **Q10.** Which of these is NOT something pseudocode is good for? C
# a) Planning decision logic before coding   b) Communicating an algorithm to someone who doesn't code   c) Running directly on a computer   d) Catching gaps in your logic early
#
# **Q11.** Put these steps in the correct order for an algorithm that decides if a number is even or odd: A
#
# I. Divide the number by 2 and check the remainder
# II. Get the number
# III. If the remainder is 0, say "even", otherwise say "odd"
#
# a) II, I, III   b) I, II, III   c) III, II, I   d) II, III, I
#
# **Q12.** Decomposition, pattern recognition, abstraction, and algorithms are known together as what? A
# a) The four pillars of computational thinking   b) The four laws of Python   c) The Boolean operators   d) The control flow tools

# %% [markdown]
# ### Conditionals & control flow (Q13 to Q16)
#
# **Q13.** What is the key difference between using `elif` and writing a second, separate `if` statement? B
# a) There is no difference   b) `elif` only runs if the previous condition was False; a separate `if` always gets checked regardless   c) `elif` is just faster to type   d) A separate `if` statement is not valid Python
#
# **Q14.** What prints? B
# ```
# age = 15
# if age < 12:
#     print("child")
# elif age < 18:
#     print("teen")
# else:
#     print("adult")
# ```
# a) child   b) teen   c) adult   d) nothing prints
#
# **Q15.** For Nova Cinema's pricing, which order should the age check happen in to correctly assign the base price? B
# a) Check adult first, then child, then senior   b) Check child first, then senior, then everyone else is adult   c) Order doesn't matter at all   d) Check senior first, then adult, then child
#
# **Q16.** If none of the conditions in an if/elif chain are True and there is no `else` block, what happens? C
# a) Python raises an error   b) The first branch runs anyway   c) Nothing runs; execution just continues to the next line   d) All branches run

# %% [markdown]
# ### Booleans (Q17 to Q20)
#
# **Q17.** What are the three core Boolean operators in Python? B
# a) add, subtract, multiply   b) and, or, not   c) equal, greater, less   d) true, false, maybe
#
# **Q18.** What does `True and False or True` evaluate to? A
# a) True   b) False   c) None   d) Error
#
# **Q19.** A student writes `if age = 18:` intending to check whether age equals 18. What actually happens? B
# a) It works correctly   b) Python raises a SyntaxError, because `=` is assignment, not comparison   c) It silently checks nothing   d) It always evaluates to True
#
# **Q20.** Which Boolean expression correctly represents "this showing is a matinee AND the customer is a member"? B
# a) `is_matinee | is_member`   b) `is_matinee and is_member`   c) `is_matinee, is_member`   d) `is_matinee or is_member`

# %%
# Part 5: Record your answers here. Replace None with the letter of your answer, as a string, e.g. "b"
knowledge_check_answers = {
    1: B,  2: B,  3: C,  4: C,
    5: D,  6: A,  7: B,  8: B,
    9: B,  10: C, 11: A, 12: A,
    13: B, 14: B, 15: B, 16: C,
    17: B, 18: A, 19: B, 20: B,
}

print(knowledge_check_answers)

# %% [markdown]
# ---
# ## Before you submit, check that:
# - [ ] Part 1 prints both the regular and discounted combo totals
# - [ ] Part 2 shows your hand-worked reasoning and the code confirms it
# - [ ] Part 3 has complete pseudocode someone else could follow
# - [ ] Part 4 correctly prices all four rows in the test table (test each one before submitting)
# - [ ] Part 5 knowledge check is fully filled in
# - [ ] The notebook is saved to your GitHub repo in the `labs` folder
