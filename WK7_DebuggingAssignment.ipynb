# %% [markdown]
# ### WK7 CISC 1300 Intro to Computing - DEBUGGING ASSIGNMENT
#
# Every scenario below has working-looking Python code that contains **bugs**. Some are syntax errors, some are runtime errors, and some are logic errors that run fine but give the wrong answer — read carefully.
#
# **For each question:**
# 1. Run the code cell and read any error message Python gives you (or check the output against what the scenario asks for).
# 2. Fix the bug(s) directly in the code cell.
# 3. Re-run until it works correctly.
# 4. In the markdown cell below it, replace `*Your answer here.*` with **1–2 sentences** explaining what was wrong and why your fix corrects it.

# %% [markdown]
# ---
# ## Question 1: Mission Control
#
# NASA needs a function that announces a launch countdown greeting. Run `launch_greeting()` and get Houston talking.

# %%
def launch_greeting(mission_name):
    print("T-minus liftoff for mission: " + mission_name)

launch_greeting("Artemis")

# %% [markdown]
# **What did you fix, and why?**
# I added the missing colon after def launch_greeting(mission_name). Function definitions need a colon before the indented body.

# %% [markdown]
# ---
# ## Question 2: Pizza Palace
#
# The Pizza Palace order screen should tell the customer whether their order qualifies for free delivery (orders of $15 or more).

# %%
order_total = 18.50

if order_total >= 15:
    print("Free delivery!")
else:
    print("Delivery fee applies.")

# %% [markdown]
# **What did you fix, and why?**
#
# I added the missing colon after if order_total >= 15. An if statement needs a colon at the end of its condition.

# %% [markdown]
# ---
# ## Question 3: Dragon's Hoard
#
# A dragon is counting gold coins in its hoard. The loop below should print how much gold it has after adding coins one at a time, 1 through 5.

# %%
gold = 0
for coin in range(1, 5):
    gold = gold + coin
print("Total gold:", gold)

# %% [markdown]
# **What did you fix, and why?**
#
# *Your answer here.*

# %% [markdown]
# ---
# ## Question 4: Superhero HQ
#
# The Superhero Roster system should welcome a hero by name and tell them their hero level.

# %%
hero_name = "Nightfall"
hero_level = 7

print("Welcome, " + hero_name + "! Your level is " + str(hero_level))

# %% [markdown]
# **What did you fix, and why?**
#
# I changed hero_level to str(hero_level). A string can't be joined to an integer with +, so the number must be converted to text first.

# %% [markdown]
# ---
# ## Question 5: Alarm Clock
#
# This snooze-button simulator should count down snooze attempts from 3 to 0 and then stop.

# %%
snoozes_left = 3
while snoozes_left > 0:
    print("Snoozing... attempts left:", snoozes_left)
    snoozes_left = snoozes_left - 1

# %% [markdown]
# **What did you fix, and why?**
#
# I added snoozes_left = snoozes_left - 1 inside the loop. Without it the counter never changed, so the loop never stopped.

# %% [markdown]
# ---
# ## Question 6: Pirate Treasure Split
#
# A pirate crew of 4 wants to know how much treasure (in gold coins) each pirate gets when they split 1000 coins evenly.

# %%
total_treasure = 1000
crew_size = 4

if crew_size == 4:
    share = total_treasure / crew_size
    print("Each pirate gets:", share)

# %% [markdown]
# **What did you fix, and why?**
#
# I changed = to == in the if statement. = assigns a value, while == compares values.

# %% [markdown]
# ---
# ## Question 7: Zoo Feeding Time
#
# The zookeeper's app should calculate the average number of pounds of food eaten per animal, given 3 animals ate 12, 15, and 9 pounds.

# %%
animal1 = 12
animal2 = 15
animal3 = 9

average_food = (animal1 + animal2 + animal3) / 3
print("Average food eaten:", average_food)

# %% [markdown]
# **What did you fix, and why?**
#
# I added parentheses: (animal1 + animal2 + animal3) / 3. Division happens before addition, so only animal3 was being divided.

# %% [markdown]
# ---
# ## Question 8: Video Game Leaderboard
#
# This should print the name of the player in **last place** on a 4-player leaderboard.

# %%
leaderboard = ["Ace", "Blaze", "Comet", "Drift"]

print("Last place:", leaderboard[3])

# %% [markdown]
# **What did you fix, and why?**
#
# I changed leaderboard[4] to leaderboard[3]. Indexes start at 0, so the last of 4 items is index 3.

# %% [markdown]
# ---
# ## Question 9: Magic Spellbook
#
# A wizard's spell function should calculate the mana cost of casting a spell `power` number of times, but it never gives the answer back to the caller.

# %%
def mana_cost(power, casts):
    total = power * casts
    return total

cost = mana_cost(10, 3)
print("Total mana required:", cost)

# %% [markdown]
# **What did you fix, and why?**
#
# I added return total to the function. Without it the function gave back None instead of the answer.

# %% [markdown]
# ---
# ## Question 10: Coffee Shop Rewards
#
# Baristas want to check if a customer's `stamps` count has hit exactly 10 to earn a free drink.

# %%
stamps = 10

if stamps == 10:
    print("Free drink earned!")
else:
    print("Keep collecting stamps.")

# %% [markdown]
# **What did you fix, and why?**
#
# I added the missing colon after if stamps == 10. An if statement needs a colon at the end of its condition.

# %% [markdown]
# ---
# ## Question 11: Robot Rover Battery
#
# Mission control needs the rover's battery percentage printed as part of a status message.

# %%
battery_percent = 42
status_message = "Rover battery at " + str(battery_percent) + "%."
print(status_message)

# %% [markdown]
# **What did you fix, and why?**
#
# I changed battery_percent to str(battery_percent). A string can't be joined to an integer with +, so the number must be converted to text.

# %% [markdown]
# ---
# ## Question 12: Aquarium Fish Counter
#
# The aquarium's tracking system should print the number of fish in each of 5 tanks, tanks numbered 1 through 5.

# %%
for tank in range(1, 6):
    print("Tank", tank, "is ready for inspection.")

# %% [markdown]
# **What did you fix, and why?**
#
# I changed range(1, 5) to range(1, 6). range stops before the end number, so tank 5 was skipped.

# %% [markdown]
# ---
# ## Question 13: Bakery Order Queue
#
# The bakery wants to greet today's first customer in line by name.

# %%
customers = ["Priya", "Jordan", "Miguel"]
first_customer = customers[0]

print("Now serving: " + first_customer)

# %% [markdown]
# **What did you fix, and why?**
#
# I added first_customer = customers[0]. The variable was never created, and the first item in a list is at index 0.

# %% [markdown]
# ---
# ## Question 14: Music Playlist Shuffle
#
# This should print how many songs remain after removing 2 skipped songs from a playlist of 8.

# %%
total_songs = 8
skipped_songs = 2

remaining_songs = total_songs - skipped_songs
print(f"Remaining songs: {remaining_songs}")

# %% [markdown]
# **What did you fix, and why?**
#
# I changed remaining_song to remaining_songs. The variable name in the f-string had a typo and didn't match the defined variable.

# %% [markdown]
# ---
# ## Question 15: Haunted House Timer
#
# A haunted house attraction should count down the seconds from 5 to 1 before the doors open, then announce it's open.

# %%
seconds = 5
while seconds >= 1:
    print(seconds)
    seconds = seconds - 1
print("The doors are open!")

# %% [markdown]
# **What did you fix, and why?**
#
# I moved the "doors are open" print outside the loop by dedenting it. It was inside the loop, so it printed every time instead of once at the end.

# %% [markdown]
# ---
# ## Question 16: Weather Station
#
# This should convert a temperature from Celsius to Fahrenheit using the formula F = C * 9/5 + 32, for a 20°C reading.

# %%
celsius = 20
fahrenheit = celsius * 9 / 5 + 32
print(f"{celsius}C is equal to {fahrenheit}F")

# %% [markdown]
# **What did you fix, and why?**
#
# I changed fahrenheight to fahrenheit. The variable name in the f-string had a typo and didn't match the defined variable.

# %% [markdown]
# ---
# ## Question 17: Gym Membership Tracker
#
# The front desk app should tell a member whether they're eligible for a loyalty discount after 12 or more visits.

# %%
visits = 12

is_eligible = visits >= 12
print("Eligible for discount:", is_eligible)

# %% [markdown]
# **What did you fix, and why?**
# I added a comma after the string: print("Eligible for discount:", is_eligible). Items in print must be separated by commas.

# %% [markdown]
# ---
# ## Question 18: Library Book Return
#
# The library system should calculate the late fee for a book that is 4 days overdue, at $0.25 per day.

# %%
days_overdue = 4
fee_per_day = 0.25

late_fee = days_overdue * fee_per_day
print("Late fee: $", late_fee)

# %% [markdown]
# **What did you fix, and why?**
#
# I added a comma after the string: print("Late fee: $", late_fee). Items in print must be separated by commas.

# %% [markdown]
# ---
# ## Question 19: Ghost Town Population
#
# This function should return `True` if a town's population is below 50 (making it a ghost town) and `False` otherwise. It's being tested with a population of 30.

# %%
def is_ghost_town(population):
    if population < 50:
        return True
    return False

print(is_ghost_town(30))

# %% [markdown]
# **What did you fix, and why?**
#
# I added the missing colon after if population < 50. An if statement needs a colon at the end of its condition.

# %% [markdown]
# ---
# ## Question 20: Final Boss: Treasure Vault
#
# The vault cracking program should try PIN codes 1 through 3, and print a success message only when it reaches PIN 3 (the correct code), without crashing partway through.

# %%
correct_pin = 3
attempt = 1

while attempt <= 3:
    if attempt == correct_pin:
        print("Vault unlocked on attempt", attempt)
    attempt = attempt + 1

# %% [markdown]
# **What did you fix, and why?**
#
# I added the missing colon after while attempt <= 3. A while statement needs a colon at the end of its condition.
