# %% [markdown]
# <a href="https://colab.research.google.com/github/juemoore-prog/Rere/blob/main/Copy_of_3340_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab: From Pseudocode to Python
#
# **1300: Introduction to Computing**
#
# In this lab you will practice the two step process we covered in class.
# For each question, first write your pseudocode in the markdown cell
# provided, using the keywords from class: START, INPUT, SET, OUTPUT, IF,
# THEN, ELSE, ENDIF, and END. Once your pseudocode is solid, translate it
# into real Python code in the code cell that follows.
#
# **Instructions**
# - **Make a copy of this lab by going to file -> Save a copy in drive.**
# - Double click a pseudocode cell to edit it, then run the cell to see it formatted.
# - Write your pseudocode before you write any Python code, even if the answer feels obvious.
# - Test every program by running its code cell and entering a few different values.
# - Questions 1 through 8 use only sequence, input, output, and variables.
# - Questions 9 through 15 each add one IF and ELSE decision.

# %% [markdown]
# ## Worked Example: Rectangle Perimeter
#
# This example is filled in completely so you can see the expected format
# before you start on your own. It asks the user for the length and width
# of a rectangle and outputs the perimeter.

# %% [markdown]
# **Pseudocode**
#
# ```
# START
#   INPUT length
#   INPUT width
#   SET perimeter = 2 * (length + width)
#   OUTPUT perimeter
# END
# ```

# %%
# Worked Example: Python Code
length = float(input("Enter the length: "))
width = float(input("Enter the width: "))
perimeter = 2 * (length + width)
print(perimeter)
# Out:
# Enter the length: 5
# Enter the width: 6
# 22.0

# %% [markdown]
# ---

# %% [markdown]
# ## Part A: Sequence, Variables, and Input/Output

# %% [markdown]
# ### Question 1: Print Your Name and Course
#
# Write a program that outputs your name on one line and the course name, 1300: Introduction to Computing, on the next line.
#
# **Requirements**
# - No input is needed for this question.
# - Use two separate OUTPUT steps in your pseudocode.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# OUTPUT "Jurmayne moore"
#   OUTPUT "1300: Introduction to Computing"
# END
# ```

# %%
# Question 1: Python Code
# Write your code below.
print("Jurmayne moore")
print("1300: Introduction to Computing")

# %% [markdown]
# ---

# %% [markdown]
# ### Question 2: Greet the User
#
# Write a program that asks the user for their name and then outputs a greeting that includes the name they entered, such as Hello, Sam!
#
# **Requirements**
# - Use one INPUT step to collect the name.
# - Use one OUTPUT step to display the greeting.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
#   INPUT Jurmayne
#   OUTPUT "Hello, " + Jurmayne + "!"
# END
# ```

# %%
# Question 2: Python Code
# Write your code below.
name = input("Jurmayne: ")
print("Hello, " + Jurmayne + "!")

# %% [markdown]
# ---

# %% [markdown]
# ### Question 3: Add Two Numbers
#
# Write a program that asks the user for two numbers and outputs their sum.
#
# **Requirements**
# - Use two separate INPUT steps, one for each number.
# - Store the sum in its own variable before you output it.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT num1
#   INPUT num2
#   SET sum = num1 + num2
#   OUTPUT sum
# END
# ```

# %%
# Question 3: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 4: Average of Three Test Scores
#
# Write a program that asks the user for three test scores and outputs the average of the three. This is the same example we broke down line by line in class, so use it to check your pseudocode habits.
#
# **Requirements**
# - Use three separate INPUT steps.
# - Store the sum in a variable named total before dividing.
# - Store the final result in a variable named average before you output it.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT score1
#   INPUT score2
#   INPUT score3
#   SET total = score1 + score2 + score3
#   SET average = total / 3
#   OUTPUT average
# END
# ```

# %%
# Question 4: Python Code
# Write your code below.
score1 = float(input("Enter the first score: "))
score2 = float(input("Enter the second score: "))
score3 = float(input("Enter the third score: "))
total = score1 + score2 + score3
average = total / 3
print(average)

# %% [markdown]
# ---

# %% [markdown]
# ### Question 5: Rectangle Area
#
# Write a program that asks the user for the length and width of a rectangle and outputs its area.
#
# **Requirements**
# - Use two separate INPUT steps, one for length and one for width.
# - Store the area in its own variable before you output it.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT length
#   INPUT width
#   SET area = length * width
#   OUTPUT area
# END
# ```

# %%
# Question 5: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 6: Minutes to Hours and Minutes
#
# Write a program that asks the user for a number of minutes and outputs how many full hours and how many leftover minutes that equals. For example, 130 minutes should output 2 hours and 10 minutes.
#
# **Requirements**
# - Store the number of full hours in one variable.
# - Store the leftover minutes in a second variable.
# - Output both values, either together or in two separate OUTPUT steps.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT totalMinutes
#   SET hours = totalMinutes / 60
#   SET leftoverMinutes = totalMinutes MOD 60
#   OUTPUT hours
#   OUTPUT leftoverMinutes
# END
# ```

# %%
# Question 6: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 7: Fahrenheit to Celsius
#
# Write a program that asks the user for a temperature in Fahrenheit and outputs the equivalent temperature in Celsius. Use the formula Celsius equals (Fahrenheit minus 32) times 5, divided by 9.
#
# **Requirements**
# - Use one INPUT step for the Fahrenheit temperature.
# - Store the converted value in its own variable before you output it.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT fahrenheit
#   SET celsius = (fahrenheit - 32) * 5 / 9
#   OUTPUT celsius
# END
# ```

# %%
# Question 7: Python Code
# Write your code below.
fahrenheit = float(input("Enter the temperature in Fahrenheit: "))
celsius = (fahrenheit - 32) * 5 / 9
print(celsius)

# %% [markdown]
# ---

# %% [markdown]
# ### Question 8: Simple Interest Calculator
#
# Write a program that asks the user for a principal amount, an annual interest rate as a decimal, and a number of years, then outputs the simple interest earned. Use the formula interest equals principal times rate times years.
#
# **Requirements**
# - Use three separate INPUT steps.
# - Store the result in its own variable before you output it.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT principal
#   INPUT rate
#   INPUT years
#   SET interest = principal * rate * years
#   OUTPUT interest
# END
# ```

# %%
# Question 8: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ## Part B: Adding a Single Conditional

# %% [markdown]
# ### Question 9: Pass or Fail
#
# Write a program that asks the user for a test score and outputs Pass if the score is 60 or higher, and Fail otherwise. This is the same example we broke down in class.
#
# **Requirements**
# - Use exactly one IF, one ELSE, and one ENDIF in your pseudocode.
# - Only one of the two possible messages should ever be displayed.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT score
#   IF score >= 60 THEN
#     OUTPUT "Pass"
#   ELSE
#     OUTPUT "Fail"
#   ENDIF
# END
# ```

# %%
# Question 9: Python Code
# Write your code below.
score = float(input("Enter the test score: "))
if score >= 60:
    print("Pass")
else:
    print("Fail")

# %% [markdown]
# ---

# %% [markdown]
# ### Question 10: Even or Odd
#
# Write a program that asks the user for a whole number and outputs whether it is Even or Odd.
#
# **Requirements**
# - Use the MOD operator in your pseudocode to test divisibility by 2.
# - Use exactly one IF, one ELSE, and one ENDIF.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT number
#   IF number MOD 2 == 0 THEN
#     OUTPUT "Even"
#   ELSE
#     OUTPUT "Odd"
#   ENDIF
# END
# ```

# %%
# Question 10: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 11: Eligible to Vote
#
# Write a program that asks the user for their age and outputs a message saying whether they are eligible to vote. A person is eligible once they turn 18.
#
# **Requirements**
# - Use a comparison operator that includes the boundary value of 18.
# - Use exactly one IF, one ELSE, and one ENDIF.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT age
#   IF age >= 18 THEN
#     OUTPUT "You are eligible to vote."
#   ELSE
#     OUTPUT "You are not eligible to vote yet."
#   ENDIF
# END
# ```

# %%
# Question 11: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 12: Speeding Ticket Check
#
# Write a program that asks the user for a driver's speed in miles per hour and outputs Ticket if the speed is over 65, and Safe otherwise.
#
# **Requirements**
# - Use a strict greater than comparison, since exactly 65 should count as Safe.
# - Use exactly one IF, one ELSE, and one ENDIF.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT speed
#   IF speed > 65 THEN
#     OUTPUT "Ticket"
#   ELSE
#     OUTPUT "Safe"
#   ENDIF
# END
# ```

# %%
# Question 12: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 13: Discount Eligibility
#
# Write a program that asks the user for the total amount of their purchase and outputs You get a discount! if the total is 100 or more, and No discount this time. otherwise.
#
# **Requirements**
# - Use a comparison operator that includes the boundary value of 100.
# - Use exactly one IF, one ELSE, and one ENDIF.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT total
#   IF total >= 100 THEN
#     OUTPUT "You get a discount!"
#   ELSE
#     OUTPUT "No discount this time."
#   ENDIF
# END
# ```

# %%
# Question 13: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 14: Above or Below Average
#
# Write a program that asks the user for their test score and outputs Above average if the score is greater than 75, and Average or below otherwise.
#
# **Requirements**
# - Use a strict greater than comparison against 75.
# - Use exactly one IF, one ELSE, and one ENDIF.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT score
#   IF score > 75 THEN
#     OUTPUT "Above average"
#   ELSE
#     OUTPUT "Average or below"
#   ENDIF
# END
# ```

# %%
# Question 14: Python Code
# Write your code below.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 15: Password Length Check
#
# Write a program that asks the user to enter a password and outputs Strong enough if the password is at least 8 characters long, and Too short otherwise.
#
# **Requirements**
# - Store the length of the password in its own variable before comparing it.
# - Use exactly one IF, one ELSE, and one ENDIF.

# %% [markdown]
# **Pseudocode**
#
# Double click this cell and replace the template below with your own pseudocode.
#
# ```
# START
# INPUT password
#   SET length = LENGTH(password)
#   IF length >= 8 THEN
#     OUTPUT "Strong enough"
#   ELSE
#     OUTPUT "Too short"
#   ENDIF
# END
# ```

# %%
# Question 15: Python Code
# Write your code below.
password = input("Enter a password: ")
length = len(password)
if length >= 8:
    print("Strong enough")
else:
    print("Too short")

# %% [markdown]
# ---

# %% [markdown]
# ## You're Finished
#
# Save your notebook and upload it to your GitHub, then submit your GitHub link to Brightspace.
